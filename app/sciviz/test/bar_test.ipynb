# %%
import matplotlib.pyplot as plt
import seaborn as sns
from fun import bar, error_parameters

# %%
iris = sns.load_dataset('iris')
iris['size'] = iris['sepal_length'].apply(lambda x: 'big' if x > 5.5 else 'small')

# %% [markdown]
# Simple barplot with x and y variables.

# %%
ax = bar(iris, 'species', 'sepal_length')

# %% [markdown]
# Add color variable.

# %%
ax = bar(iris, 'species', 'sepal_length', color='species', alpha = 1)

# %% [markdown]
# Add another color variable and color palette.

# %%
ax = bar(iris, 'species', 'sepal_length', color='size', color_pal=['#FEED70', '#603479'])

# %% [markdown]
# Change stat and do count plot.

# %%
ax = bar(iris, 'species', 'sepal_length', stat='count')

# %% [markdown]
# Change color order.

# %%
ax = bar(iris, 'species', 'sepal_length', color='species', color_order=['virginica', 'versicolor', 'setosa'])

# %% [markdown]
# Change order and color order.

# %%
ax = bar(iris, 'species', 'sepal_length', color='species', order=['virginica', 'versicolor', 'setosa'], 
         color_order=['virginica', 'versicolor', 'setosa'])

# %% [markdown]
# Change fill and width.

# %%
ax = bar(iris, 'species', 'sepal_length', color='species', width=0.8, fill=False, edgecolor=None, legend=None)

# %% [markdown]
# Add red edgecolor and errorbars.

# %%
ax = bar(iris, 'species', 'sepal_length', fill=False, edgecolor='red', 
         errorbar = error_parameters())

# %% [markdown]
# Customize errorbars.

# %%
ax = bar(iris, 'species', 'sepal_length', fill=False, edgecolor='red', 
         errorbar = error_parameters(errorbar=('sd', 2), color_pal=['red'], linestyle='--', linewidth=2, capsize=0.1))

# %% [markdown]
# Change orientation and alpha.

# %%
ax = bar(iris, 'sepal_length', 'species', color='species', orient='h', alpha=0.3, legend=None)
