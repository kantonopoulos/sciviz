# %%
import matplotlib.pyplot as plt
import seaborn as sns
import sciviz

# %%
iris = sns.load_dataset('iris')
iris['size'] = iris['sepal_length'].apply(lambda x: 'big' if x > 5.5 else 'small')

# %%
ax = sciviz.jitter(iris, 'sepal_length', 'species', color='species', orient='h', crossbar=sciviz.crossbar_parameters(barstyle='|'))
# Out:
# c:\Users\kanto\anaconda3\Lib\site-packages\sciviz\src\jitter.py:84: UserWarning:
# The palette list has fewer values (1) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   sns.pointplot(

# %% [markdown]
# Simple jitter with x and y variables.

# %%
ax = sciviz.jitter(iris, 'species', 'sepal_length')

# %% [markdown]
# Add color variable.

# %%
ax = sciviz.jitter(iris, 'species', 'sepal_length', color='species')

# %% [markdown]
# Add color based on a different variable with and without dodge and different color palette.

# %%
ax = sciviz.jitter(iris, 'species', 'petal_length', color='size', color_pal=['#FFFF80', '#603479'])

# %%
ax = sciviz.jitter(iris, 'species', 'petal_length', color='size', dodge=True, color_pal=['#FFFF80', '#603479'])

# %% [markdown]
# Change color order.

# %%
ax = sciviz.jitter(iris, 'species', 'sepal_length', color='species', color_order=['virginica', 'versicolor', 'setosa'])

# %% [markdown]
# Change color order and order.

# %%
ax = sciviz.jitter(iris, 'species', 'sepal_length', color='species', order=['virginica', 'versicolor', 'setosa'],
            color_order=['virginica', 'versicolor', 'setosa'])

# %% [markdown]
# Change marker size and alpha. Remove legend.

# %%
ax = sciviz.jitter(iris, 'species', 'sepal_length', color='species', size=100, alpha=0.5, legend=None)

# %% [markdown]
# Change orientation and jitter (False or number).

# %%
ax = sciviz.jitter(iris, 'sepal_length', 'species', color='species', orient='h', jitter=False)

# %%
ax = sciviz.jitter(iris, 'sepal_length', 'species', color='species', orient='h', jitter=0.3)

# %% [markdown]
# Add crossbars.

# %%
ax = sciviz.jitter(iris, 'species', 'sepal_length', color='species', 
            crossbar=sciviz.crossbar_parameters())
# Out:
# c:\Users\kanto\anaconda3\Lib\site-packages\sciviz\src\jitter.py:84: UserWarning:
# The palette list has fewer values (1) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   sns.pointplot(

# %% [markdown]
# Add crossbars that are dodged.

# %%
ax = sciviz.jitter(iris, 'species', 'petal_length', color='size', color_pal=['#FFFF80', '#603479'], dodge=True, 
            crossbar=sciviz.crossbar_parameters(color_val='size', color_pal=['black'], barstyle='_', barsize=20, barwidth=3))
# Out:
# c:\Users\kanto\anaconda3\Lib\site-packages\sciviz\src\jitter.py:84: UserWarning:
# The palette list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.pointplot(

# %% [markdown]
# Customize crossbars.

# %%
ax = sciviz.jitter(iris, 'species', 'sepal_length', color_pal=['black'], size=100, alpha=0.5,
            crossbar=sciviz.crossbar_parameters(color_val='size', color_pal=['blue', 'red'], barstyle='o', barsize=20, barwidth=3))
# Out:
# c:\Users\kanto\anaconda3\Lib\site-packages\sciviz\src\jitter.py:65: UserWarning:
# The palette list has fewer values (1) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   sns.stripplot(
