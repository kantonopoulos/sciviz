# %%
import matplotlib.pyplot as plt
import seaborn as sns
import sciviz

# %%
iris = sns.load_dataset('iris')
iris['size'] = iris['sepal_length'].apply(lambda x: 'big' if x > 5.5 else 'small')

# %% [markdown]
# Simple one variable histogram.

# %%
ax = sciviz.histogram(iris, 'sepal_length')

# %% [markdown]
# Increase number of bins.

# %%
ax = sciviz.histogram(iris, 'sepal_length', bins=30)

# %%
ax = sciviz.histogram(iris, 'sepal_length', binwidth=0.2)

# %% [markdown]
# Change color.

# %%
ax = sciviz.histogram(iris, 'sepal_length', bins=10, color_pal='green')
# Out:
# c:\Users\kanto\anaconda3\Lib\site-packages\sciviz\src\histogram.py:37: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(

# %% [markdown]
# Add color variable.

# %%
ax = sciviz.histogram(iris, 'sepal_length', color='species', bins = 20, alpha=0.5)

# %% [markdown]
# Remove edge color and legend.

# %%
ax = sciviz.histogram(iris, 'sepal_length', color='species', bins = 20, edgecolor=None, legend=None)

# %% [markdown]
# Change color order.

# %%
ax = sciviz.histogram(iris, 'sepal_length', color='species', bins = 20, color_order=['virginica', 'versicolor', 'setosa'])

# %% [markdown]
# Change y axis statistic from 'count' to 'percentage'.

# %%
ax = sciviz.histogram(iris, 'sepal_length', stat='percent', bins=10)
