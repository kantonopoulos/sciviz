# %%
import matplotlib.pyplot as plt
import seaborn as sns
from point import point
from histogram import histogram
from boxplot import boxplot
from bar import bar
from sciviz import sciviz
from theme import theme

# %%
iris = sns.load_dataset('iris')
iris['size'] = iris['sepal_length'].apply(lambda x: 'big' if x > 5.5 else 'small')

# Create the visualization with faceting by species
ax = sciviz(iris, height=5, aspect=1)
ax = bar(ax=ax, data=iris, y='species', x="sepal_length", color='size', stat='mean', edge_color='blue', errorbar=('sd', 2), errorbar_linestyle='--', errorbar_linewidth=2, errorbar_capsize=0, errorbar_color='red', palette='jama', orient='h', alpha = 0.2, bar_width=0.4, show_legend=True)

'''user_labels = {'Size': ['Small', 'Big']}
ax = theme(ax, 
           title="Iris Dataset", 
           subtitle="Sepal Length by Species", 
           title_size=14,
           xticks=[0, 1, 2],
           xticks_labels=['setosa', 'Versicolor', 'Virginica'],
           theme="classic", 
           legend=True,
           legend_labels=user_labels, 
           legendtitles_size=11, 
           legendtitles_weight="bold", 
           legendlabels_size=10, 
           legendlabels_weight="normal",
           legend_pos="side")'''

plt.show()

# %%
iris = sns.load_dataset('iris')
iris['size'] = iris['sepal_length'].apply(lambda x: 'big' if x > 5.5 else 'small')

# Create the visualization with faceting by species
ax = sciviz(iris, height=5, aspect=1)
ax = boxplot(ax=ax, data=iris, x='species', y="sepal_length", color='size', orient='v', alpha = 0.8, palette=['white', 'white'], box_width=0.8, points=True, points_color='black', outliers=False, format_labels=False)

'''user_labels = {'Size': ['Small', 'Big']}
ax = theme(ax, 
           title="Iris Dataset", 
           subtitle="Sepal Length by Species", 
           title_size=14,
           xticks=[0, 1, 2],
           xticks_labels=['setosa', 'Versicolor', 'Virginica'],
           theme="classic", 
           legend=True,
           legend_labels=user_labels, 
           legendtitles_size=11, 
           legendtitles_weight="bold", 
           legendlabels_size=10, 
           legendlabels_weight="normal",
           legend_pos="side")'''

plt.show()

# %%
iris = sns.load_dataset("iris")

# Create the visualization with faceting by species
ax = sciviz(iris, height=5, aspect=1)
ax = histogram(ax=ax, data=iris, x="sepal_length", alpha = 0.8, bins=10, binwidth=0.5, hist_color='white', palette="jama", format_labels=False, show_legend=False)

user_labels = {'Species': ['setossa', 'virginica', 'versicolor']}
'''ax = theme(ax, 
           title="Iris Dataset", 
           subtitle="Sepal Length by Species", 
           title_size=14,
           theme="classic", 
           legend=True,
           legend_labels=user_labels, 
           legendtitles_size=11, 
           legendtitles_weight="bold", 
           legendlabels_size=10, 
           legendlabels_weight="normal",
           legend_pos="bottom")'''

plt.show()

# %%
iris = sns.load_dataset("iris")

# Create the visualization with faceting by species
ax = sciviz(iris, height=5, aspect=1)
ax = point(ax=ax, data=iris, x="sepal_length", y="sepal_width", color='species', size='sepal_length', alpha = 0.8, marker_size = 50, marker_style = 'D', format_labels=False, show_legend=False)
user_labels = {'Species': ['setossa', 'virginica', 'versicolor'], 'sepal_length': ['4.8', '15', '6.0', '6.6', '7.2', '7.8']}

'''ax = theme(ax, 
           title="Iris Dataset", 
           subtitle="Sepal Length by Species", 
           theme="classic", 
           xlab="Sepal Length 2", 
           ylab="Sepal Width 2",
           xlim=[3.5, 8.5],
           ylim=[1.5, 5],
           xticks=[4, 5, 6, 7, 8],
           xticks_labels=[4, 5, 6, 7, 8],
           xticks_angle=90,
           yticks=[],
           yticks_labels=[],
           yticks_angle=90,
           title_size=14,
           title_weight="normal",
           subtitle_size=11,
           subtitle_weight="bold",
           axislabel_size=12,
           axislabel_weight="normal",
           ticklabel_size=8,
           legend=True,
           legend_labels=user_labels, 
           legendtitles_size=11, 
           legendtitles_weight="bold", 
           legendlabels_size=10, 
           legendlabels_weight="normal",
           legend_pos=['side', 1.15, 0.5])'''
plt.show()
