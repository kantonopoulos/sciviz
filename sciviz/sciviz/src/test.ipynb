# %%
import matplotlib.pyplot as plt
import seaborn as sns
from point import point
from histogram import histogram
from boxplot import boxplot
from bar import bar
from jitter import jitter
from line import line
from sciviz import sciviz
from theme import theme
from violin import violin
from pie import pie
from venn import venn
from euler import euler
from heatmap import heatmap

# %%
iris = sns.load_dataset("iris")
iris['size'] = iris['sepal_length'].apply(lambda x: 'big' if x > 5.5 else 'small')
col_annot = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
col_pal = ['red', 'red', 'blue', 'blue']
#species = iris.pop("species")  
ax = sciviz(height=6, aspect=1)
heatmap(ax, iris, cluster_rows=True, show_cbar=True, cbar_ticks=[2, 4, 6], cbar_lim=[1,7], cluster_cols=True, row_annot=['species', 'size'], row_pal=['jama', 'deep'], col_annot=col_annot, col_pal=col_pal)
plt.show()

# %%
iris = sns.load_dataset("iris")
iris['size'] = iris['sepal_length'].apply(lambda x: 'big' if x > 5.5 else 'small')
ax = sciviz(iris, height=5, aspect=1)
euler(ax, iris, group="size", var="petal_width", alpha=0.9, label_weight='normal', innertext_color='black', innertext_size=10, format_labels=False)
plt.show()

# %%
iris = sns.load_dataset("iris")
ax = sciviz(iris, height=5, aspect=1)
euler(ax, iris, group="species", var="sepal_length", palette='deep', alpha=0.9, label_weight='bold', innertext_color='black', innertext_size=10, format_labels=True)
plt.show()

# %%
iris = sns.load_dataset("iris")

# Create the visualization with faceting by species
ax = sciviz(iris, height=5, aspect=1)
ax = pie(ax=ax, data=iris, group='species', alpha=1, donut=True, innertext=True, innertext_color='white', innertext_format='%1.2f%%', labels=True, format_labels=True)

# %%
flights = sns.load_dataset("flights")
flights['season'] = flights['month'].apply(lambda x: 'winter' if x in ['Jan', 'Feb', 'Mar', 'Oct', 'Nov', 'Dec'] else 'summer')

# Create the visualization with faceting by species
ax = sciviz(flights, height=5, aspect=1)
ax = line(ax=ax, data=flights, x='year', y='passengers', color='season', palette='deep', errorbar=('ci', 95), errorbar_style='bars', markers=True, alpha = 0.8, format_labels=False, show_legend=True)
user_labels = {'Season': ['winter', 'summer']}

'''ax = theme(ax, 
           title="Flights Dataset", 
           subtitle="Passengers over time", 
           theme="ticks", 
           xlab="Time", 
           ylab="P/F",
           title_size=14,
           title_weight="normal",
           subtitle_size=11,
           subtitle_weight="bold",
           axislabel_size=12,
           axislabel_weight="normal",
           ticklabel_size=8,
           legend=True,
           legend_labels=user_labels, 
           legendtitles_size=11, 
           legendtitles_weight="normal", 
           legendlabels_size=10, 
           legendlabels_weight="normal",
           legend_pos='side')'''
plt.show()

# %%
iris = sns.load_dataset("iris")
iris['size'] = iris['sepal_length'].apply(lambda x: 'big' if x > 5.5 else 'small')

# Create the visualization with faceting by species
ax = sciviz(iris, height=5, aspect=1)
ax = point(ax=ax, data=iris, x="sepal_length", y="sepal_width", color='species', style='size', alpha = 0.8, marker_size = 5, marker_style = 'D', format_labels=False, show_legend=True)
user_labels = {'Species': ['setossa', 'virginica', 'versicolor'], 'sepal_length': ['4.8', '15', '6.0', '6.6', '7.2', '7.8']}

'''ax = theme(ax, 
           title="Iris Dataset", 
           subtitle="Sepal Length by Species", 
           theme="classic", 
           xlab="Sepal Length 2", 
           ylab="Sepal Width 2",
           xlim=[3.5, 8.5],
           ylim=[1.5, 5],
           xticks=[4, 5, 6, 7, 8],
           xticks_labels=[4, 5, 6, 7, 8],
           xticks_angle=90,
           yticks=[],
           yticks_labels=[],
           yticks_angle=90,
           title_size=14,
           title_weight="normal",
           subtitle_size=11,
           subtitle_weight="bold",
           axislabel_size=12,
           axislabel_weight="normal",
           ticklabel_size=8,
           legend=True,
           legend_labels=user_labels, 
           legendtitles_size=11, 
           legendtitles_weight="bold", 
           legendlabels_size=10, 
           legendlabels_weight="normal",
           legend_pos=['side', 1.15, 0.5])'''
plt.show()

# %%
iris = sns.load_dataset('iris')
iris['size'] = iris['sepal_length'].apply(lambda x: 'big' if x > 5.5 else 'small')

# Create the visualization with faceting by species
ax = sciviz(iris, height=5, aspect=1)
ax = violin(ax=ax, data=iris, y='size', x='sepal_width', color='species', split=False, orient='h', alpha=1, show_legend=True, box=True, format_labels=False)

user_labels = {'Species': ['Setosa', 'Versicolor', 'Virginica']}
'''ax = theme(ax, 
           title="Iris Dataset", 
           subtitle="Sepal Length by Species", 
           title_size=14,
           #yticks=[0, 1, 2],
           yticks_angle=90,
           #yticks_labels=['Setosa', 'Versicolor', 'Virginica'],
           theme="classic", 
           legend=True,
           legend_labels=user_labels, 
           legendtitles_size=11, 
           legendtitles_weight="bold", 
           legendlabels_size=10, 
           legendlabels_weight="normal",
           legend_pos="bottom")'''

plt.show()

# %%
iris = sns.load_dataset('iris')
iris['size'] = iris['sepal_length'].apply(lambda x: 'big' if x > 5.5 else 'small')

# Create the visualization with faceting by species
ax = sciviz(iris, height=5, aspect=1)
ax = jitter(ax=ax, data=iris, x='species', y='sepal_length', points_color='black', orient='v', alpha=1, dodge=True, format_labels=False, show_legend=True)

'''user_labels = {'Size': ['Small', 'Big']}
ax = theme(ax, 
           title="Iris Dataset", 
           subtitle="Sepal Length by Species", 
           title_size=14,
           xticks=[0, 1, 2],
           xticks_labels=['setosa', 'Versicolor', 'Virginica'],
           theme="classic", 
           legend=True,
           legend_labels=user_labels, 
           legendtitles_size=11, 
           legendtitles_weight="bold", 
           legendlabels_size=10, 
           legendlabels_weight="normal",
           legend_pos="side")'''

plt.show()

# %%
iris = sns.load_dataset('iris')
iris['size'] = iris['sepal_length'].apply(lambda x: 'big' if x > 5.5 else 'small')

# Create the visualization with faceting by species
ax = sciviz(iris, height=5, aspect=1)
ax = bar(ax=ax, data=iris, y='species', x="sepal_length", color='size', stat='mean', edge_color='blue', errorbar=('sd', 2), errorbar_linestyle='--', errorbar_linewidth=2, errorbar_capsize=0, errorbar_color='red', palette='jama', orient='h', alpha = 0.2, bar_width=0.4, format_labels=False, show_legend=True)

'''user_labels = {'Size': ['Small', 'Big']}
ax = theme(ax, 
           title="Iris Dataset", 
           subtitle="Sepal Length by Species", 
           title_size=14,
           xticks=[0, 1, 2],
           xticks_labels=['setosa', 'Versicolor', 'Virginica'],
           theme="classic", 
           legend=True,
           legend_labels=user_labels, 
           legendtitles_size=11, 
           legendtitles_weight="bold", 
           legendlabels_size=10, 
           legendlabels_weight="normal",
           legend_pos="side")'''

plt.show()

# %%
iris = sns.load_dataset('iris')
iris['size'] = iris['sepal_length'].apply(lambda x: 'big' if x > 5.5 else 'small')

# Create the visualization with faceting by species
ax = sciviz(iris, height=5, aspect=1)
ax = boxplot(ax=ax, data=iris, x='species', y="sepal_length", color='size', orient='v', alpha = 0.8, median_color='red', palette=['white', 'white'], box_color='white', box_width=0.8, points=True, points_color='black', outliers=False, format_labels=False)

'''user_labels = {'Size': ['Small', 'Big']}
ax = theme(ax, 
           title="Iris Dataset", 
           subtitle="Sepal Length by Species", 
           title_size=14,
           xticks=[0, 1, 2],
           xticks_labels=['setosa', 'Versicolor', 'Virginica'],
           theme="classic", 
           legend=True,
           legend_labels=user_labels, 
           legendtitles_size=11, 
           legendtitles_weight="bold", 
           legendlabels_size=10, 
           legendlabels_weight="normal",
           legend_pos="side")'''

plt.show()

# %%
iris = sns.load_dataset("iris")

# Create the visualization with faceting by species
ax = sciviz(iris, height=5, aspect=1)
ax = histogram(ax=ax, data=iris, x="sepal_length", alpha = 0.8, bins=10, binwidth=0.5, hist_color='white', palette="jama", format_labels=False, show_legend=False)

user_labels = {'Species': ['setossa', 'virginica', 'versicolor']}
'''ax = theme(ax, 
           title="Iris Dataset", 
           subtitle="Sepal Length by Species", 
           title_size=14,
           theme="classic", 
           legend=True,
           legend_labels=user_labels, 
           legendtitles_size=11, 
           legendtitles_weight="bold", 
           legendlabels_size=10, 
           legendlabels_weight="normal",
           legend_pos="bottom")'''

plt.show()
