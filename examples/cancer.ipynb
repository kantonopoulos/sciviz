# %%
import matplotlib.pyplot as plt
import seaborn as sns
import sciviz

# %%
data = sciviz.load_data("cancer")
display(data)
# Out:
#           Sample GROUP    Stage  Grade     Sex    AARSD1      ABL1     ACAA1  \
# 0      AML_syn_1   AML        2    NaN  Female  3.390346  2.758852  1.707009
# 1      AML_syn_2   AML  Unknown    NaN    Male  1.422795  1.247305 -0.816163
# 2      AML_syn_3   AML        2    NaN  Female       NaN       NaN       NaN
# 3      AML_syn_4   AML  Unknown    NaN    Male  3.409418  3.383503  1.692789
# 4      AML_syn_5   AML        2    NaN  Female  5.011080  5.054630  0.127958
# ..           ...   ...      ...    ...     ...       ...       ...       ...
# 331  MYEL_syn_34  MYEL      NaN    NaN    Male       NaN       NaN       NaN
# 332  MYEL_syn_35  MYEL      NaN    NaN    Male  4.948372  3.957622  1.771119
# 333  MYEL_syn_36  MYEL      NaN    NaN    Male       NaN       NaN -0.900412
# 334  MYEL_syn_37  MYEL      NaN    NaN    Male  3.791249  2.536717  1.100585
# 335  MYEL_syn_38  MYEL      NaN    NaN  Female  1.645268  4.130089  2.147295
#
# ...
